# %% [markdown]
# # Quick demo
#
# This notebook runs the lightweight reproducibility demo (src/quick_demo.py) which generates a small CSV in docs/figures/. It is intentionally fast and avoids heavy optional dependencies.

# %%
import os
print('Running quick demo...')
os.system('python3 src/quick_demo.py')
